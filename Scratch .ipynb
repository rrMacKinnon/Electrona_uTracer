# %% [markdown]
# ### Dependencies

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
# Make a Series of random numbers between 0 and 1
s = pd.Series(np.random.rand(25))


# Make a DataFrame of random numbers between 0 and 1
df = pd.DataFrame(np.random.rand(40,13))
df.head()
# Out:
#          0         1         2         3         4         5         6   \
# 0  0.276637  0.035617  0.462761  0.217109  0.281372  0.817202  0.618068
# 1  0.080888  0.669047  0.218037  0.844760  0.385173  0.754476  0.898218
# 2  0.677581  0.797206  0.481717  0.872386  0.512318  0.990136  0.886925
# 3  0.393917  0.309528  0.533859  0.041716  0.666108  0.248758  0.105632
# 4  0.473353  0.509177  0.723748  0.302285  0.170940  0.421692  0.589762
#
#          7         8         9         10        11        12
# 0  0.960326  0.632595  0.168034  0.337520  0.160768  0.940123
# 1  0.037271  0.452083  0.618982  0.585535  0.783703  0.214275
# 2  0.228901  0.628371  0.428574  0.781884  0.589148  0.242642
# 3  0.619147  0.128691  0.316927  0.796213  0.404817  0.311090
# 4  0.124925  0.290463  0.847563  0.402577  0.925918  0.719450

# %%
df_stats = df.describe()
df_stats
# Out:
#                0          1          2          3          4
# count  10.000000  10.000000  10.000000  10.000000  10.000000
# mean    0.448423   0.558728   0.440973   0.521443   0.572034
# std     0.279007   0.260629   0.304459   0.360493   0.306013
# min     0.072926   0.195126   0.044398   0.044151   0.041554
# 25%     0.267065   0.306838   0.179236   0.220394   0.444780
# 50%     0.373466   0.611572   0.460339   0.436833   0.581419
# 75%     0.628767   0.749597   0.631280   0.906479   0.829752
# max     0.885346   0.931015   0.900491   0.980001   0.962355

# %%
# create a group of time series
num_samples = 90
group_size = 10
x = np.linspace(0, 10, num_samples)
group = np.sin(x) + np.linspace(0, 2, num_samples) + np.random.rand(group_size, num_samples) + np.random.randn(group_size, 1)
df = pd.DataFrame(group.T, index=range(0,num_samples))

# plot time series with seaborn
ax = sns.tsplot(data=df.T.values) #, err_style="unit_traces")

# Add std deviation bars to the previous plot
mean = df.mean(axis=1)
std  = df.std(axis=1)
ax.errorbar(df.index, mean, yerr=std, fmt='-o') #fmt=None to plot bars only

plt.show()
